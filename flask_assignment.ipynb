# %%
#Answer_1

Flask is a pythonic library is used to create API's and method or the function
to expose in a outer world. 
it is flask framework to provides libraries to build a light_weight web application.
It is developed by Armin Ronacher who leads an international group of python enthusiasts (POCCO).

Advantages

Integrated support for unit testing

Built-in development server and fast debugger

Restful request dispatching

Unicode base

Support for cookies

Templating jinja2

WSGI 1.0 compliant

Plus flask gives you some premier control to develop your project.

HTTP request handling function

Flask has a modular design and lightweight so that it can easy to transit into web framework with some extension

You can plug your favorite ORM

Basic fundamental API is nicely shaped and coherent

Highly flexible

It is easy to deploy the flask in production

# %%
#Asnwer_2

# %% [markdown]
# ![download.png](attachment:0a119be8-f741-40b3-9679-80946cb375d1.png)![download.png](attachment:7d149c70-2f3d-47d6-a3c5-343a873a04f0.png)

# %%
#Answer_3

App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. 

Example: In our application, the URL (“/”) is associated with the root URL. So if our site’s domain
was www.example.org and we want to add routing to “www.example.org/hello”, we would use “/hello”. 

#we use app routes

The route() decorator in Flask is used to bind an URL to a function. As a result when the URL is mentioned in the browser,
the function is executed to give the result.

# %%
#Answer_4

# %% [markdown]
# ![download.png](attachment:af28e270-936d-4223-b3db-e04a0aafc453.png)
# ![download.png](attachment:40307e12-ad03-4687-ad82-359802b1915f.png)

# %%
#Answer_5

The url_for() function is used to build a URL to the specific function dynamically.
The first argument is the name of the specified function, and then we can pass any number 
of keyword argument corresponding to the variable part of the URL.

#python code 

from flask import *  
   
app = Flask(_name_) 
@app.route('/admin')  
def admin():  
    return 'admin'  

@app.route('/librarion')  
def librarion():  
    return 'librarion'  
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'librarion':  
        return redirect(url_for('librarion'))  
    if name == 'student':  
        return redirect(url_for('student'))  
if _name_ =='_main_':  
    app.run(debug = True)
